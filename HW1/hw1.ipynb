# %%
import random
import collections

tried_letters = []

# %%
def drawGallows():
    gallows = ['''
    
    
    
    
          _
     ____|_|_____
   ''', '''
     ______
    |
    |
    |
    |
    |     _ 
    |____|_|___
    ''','''
     ______
    |     |
    |     |
    |     
    |
    |     _ 
    |____|_|___
    ''', '''
     ______
    |     |
    |     |
    |     O
    |     
    |     _ 
    |____|_|___
    ''', '''
     ______
    |     |
    |     |
    |     O
    |     |
    |     _ 
    |____|_|___
    ''', '''
     ______
    |     |
    |     |
    |    \O
    |     |
    |     _ 
    |____|_|___
    ''','''
     ______
    |     |
    |     |
    |    \O/
    |     |
    |     _ 
    |____|_|___
    ''', '''
     ______
    |     |
    |     |
    |    \O/
    |     |
    |    /_ 
    |____|_|___
    ''', '''
     ______
    |     |
    |     |
    |    \O/
    |     |
    |    /_\    
    |____|_|_____
    ''', '''
     ______
    |     |
    |     |
    |    \O/
    |     |
    |    / \
    |__________
        ''']

    return gallows

# %%
def topic():
    theme = input('Введите номер желаемой темы: \
\n 1) Журналистика \n 2) Византийская книжность \n 3) Французская кухня \n ')
    while True:
        if theme == "1" or theme == '2' or theme == '3':
            with open(theme + '.txt', 'r', encoding='utf-8') as f:
                f = [line.strip() for line in f]
            break
        else:
            theme = input('Внимание! Ввести нужно только номер: \
    \n 1) Журналистика \n 2) Византийская книжность \n 3) Французская кухня \n ')
    return f

# %%
def getWord(topic):
    word = random.choice(topic)
    return word

# %%
def checkLetter():
    while True:
        user_attempt = input('Введите букву, которая, по вашему мнению, есть в этом слове: ').lower()
        tried_letters.append(user_attempt)
        if user_attempt in tried_letters[:-1]:
            print('Вы уже пробовали эту букву, забыли?')
        elif len(user_attempt) > 1:
            print('Кажется, здесь не одна буква, я запутался...')
        elif len(user_attempt) == 0:
            print('По-моему, вы ничего не написали. Все же придумайте букву!')
        elif user_attempt not in 'ёйцукенгшщзхъфывапролджэячсмитьбю':
            print('Такой буквы в русском алфавите нет!')
        else:
            return user_attempt

# %%
def game(word):
    puzzle = len(word) * '_ '
    print(puzzle)
##    print(word)
    attempts = 0
    while attempts < 10 and ''.join(puzzle.split()) != word:
        guess = checkLetter()
        if guess in word:
            for index in range(len(word)):
                if word[index] == guess:
                    puzzle = puzzle[:index*2] + word[index] + ' ' + puzzle[(index+1)*2:]
            print(puzzle)
        else:
            print('Такой буквы в слове нет!')
            print(puzzle)
            attempts += 1
            print(drawGallows()[attempts-1])
            if attempts >= 6 and attempts <= 8:
                print('У вас осталось ', 10 - attempts, 'попытки')
            elif attempts == 9:
                print('У вас осталась', 10 - attempts, 'попытка')
            else:
                print('У вас осталось', 10 - attempts, 'попыток')
    return puzzle, word

# %%
def checkWin(game):
    if ''.join(game[0].split()) == game[1]:
        print('Поздравляю! Вас не успели повесить!')
    else:
        print('О нет! Вы проиграли... Это было слово "', game[1], '" Попробуйте сыграть еще раз.')
    goOn()

# %%
def goOn():
    tried_letters.clear()
    wish = input('Если хотите продолжить игру, введите "да": ')
    if wish.lower() == "да":
        checkWin(game(getWord(topic())))
    else:
        wish = input('Вы действительно заканчиваете игру? Введите "да" или "нет"')
        if wish.lower() == 'да':
            print('До свидания!')
        elif wish.lower() == "нет":
            checkWin(game(getWord(topic()))) 
        else:
            print('Я вас не совсем понимаю... Поэтому на всякий случай сыграем еще раз')
            checkWin(game(getWord(topic())))

# %%
def main():
    return checkWin(game(getWord(topic())))

if __name__== '__main__':
    main()
# Out:
# Введите номер желаемой темы:
#  1) Журналистика
#  2) Византийская книжность
#  3) Французская кухня
#  2
# _ _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: а
# _ а _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: о
# _ а _ о _
# Введите букву, которая, по вашему мнению, есть в этом слове: н
# _ а н о н
# Введите букву, которая, по вашему мнению, есть в этом слове: к
# к а н о н
# Поздравляю! Вас не успели повесить!
# Если хотите продолжить игру, введите "да": да
# Введите номер желаемой темы:
#  1) Журналистика
#  2) Византийская книжность
#  3) Французская кухня
#  2
# _ _ _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: ыв
# Кажется, здесь не одна буква, я запутался...
# Введите букву, которая, по вашему мнению, есть в этом слове: а
# _ _ _ _ а _
# Введите букву, которая, по вашему мнению, есть в этом слове: з
# Такой буквы в слове нет!
# _ _ _ _ а _
#
#
#
#
#
#           _
#      ____|_|_____
#
# У вас осталось 9 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: б
# Такой буквы в слове нет!
# _ _ _ _ а _
#
#      ______
#     |
#     |
#     |
#     |
#     |     _
#     |____|_|___
#
# У вас осталось 8 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: р
# Такой буквы в слове нет!
# _ _ _ _ а _
#
#      ______
#     |     |
#     |     |
#     |
#     |
#     |     _
#     |____|_|___
#
# У вас осталось 7 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: г
# Такой буквы в слове нет!
# _ _ _ _ а _
#
#      ______
#     |     |
#     |     |
#     |     O
#     |
#     |     _
#     |____|_|___
#
# У вас осталось 6 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: л
# Такой буквы в слове нет!
# _ _ _ _ а _
#
#      ______
#     |     |
#     |     |
#     |     O
#     |     |
#     |     _
#     |____|_|___
#
# У вас осталось 5 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: а
# Вы уже пробовали эту букву, забыли?
# Введите букву, которая, по вашему мнению, есть в этом слове: у
# Такой буквы в слове нет!
# _ _ _ _ а _
#
#      ______
#     |     |
#     |     |
#     |    \O
#     |     |
#     |     _
#     |____|_|___
#
# У вас осталось  4 попытки
# Введите букву, которая, по вашему мнению, есть в этом слове: о
# _ о _ _ а _
# Введите букву, которая, по вашему мнению, есть в этом слове: ш
# Такой буквы в слове нет!
# _ о _ _ а _
#
#      ______
#     |     |
#     |     |
#     |    \O/
#     |     |
#     |     _
#     |____|_|___
#
# У вас осталось  3 попытки
# Введите букву, которая, по вашему мнению, есть в этом слове: с
# Такой буквы в слове нет!
# _ о _ _ а _
#
#      ______
#     |     |
#     |     |
#     |    \O/
#     |     |
#     |    /_
#     |____|_|___
#
# У вас осталось  2 попытки
# Введите букву, которая, по вашему мнению, есть в этом слове: м
# Такой буквы в слове нет!
# _ о _ _ а _
#
#      ______
#     |     |
#     |     |
#     |    \O/
#     |     |
#     |    /_\
#     |____|_|_____
#
# У вас осталась 1 попытка
# Введите букву, которая, по вашему мнению, есть в этом слове: н
# _ о н _ а _
# Введите букву, которая, по вашему мнению, есть в этом слове: т
# Такой буквы в слове нет!
# _ о н _ а _
#
#      ______
#     |     |
#     |     |
#     |    \O/
#     |     |
#     |    /     |___________
#
# У вас осталось 0 попыток
# О нет! Вы проиграли... Это было слово " кондак " Попробуйте сыграть еще раз.
# Если хотите продолжить игру, введите "да": дда
# Вы действительно заканчиваете игру? Введите "да" или "нет"нет
# Введите номер желаемой темы:
#  1) Журналистика
#  2) Византийская книжность
#  3) Французская кухня
#  1
# _ _ _ _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: о
# _ о _ _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: к
# Такой буквы в слове нет!
# _ о _ _ _ _ _
#
#
#
#
#
#           _
#      ____|_|_____
#
# У вас осталось 9 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: м
# Такой буквы в слове нет!
# _ о _ _ _ _ _
#
#      ______
#     |
#     |
#     |
#     |
#     |     _
#     |____|_|___
#
# У вас осталось 8 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: л
# л о _ _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: т
# Такой буквы в слове нет!
# л о _ _ _ _ _
#
#      ______
#     |     |
#     |     |
#     |
#     |
#     |     _
#     |____|_|___
#
# У вас осталось 7 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: в
# Такой буквы в слове нет!
# л о _ _ _ _ _
#
#      ______
#     |     |
#     |     |
#     |     O
#     |
#     |     _
#     |____|_|___
#
# У вас осталось 6 попыток
# Введите букву, которая, по вашему мнению, есть в этом слове: н
# л о н _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: г
# л о н г _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: р
# л о н г р _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: и
# л о н г р и _
# Введите букву, которая, по вашему мнению, есть в этом слове: л
# Вы уже пробовали эту букву, забыли?
# Введите букву, которая, по вашему мнению, есть в этом слове: д
# л о н г р и д
# Поздравляю! Вас не успели повесить!
# Если хотите продолжить игру, введите "да": ыдвлао
# Вы действительно заканчиваете игру? Введите "да" или "нет"дчЯЛС
# Я вас не совсем понимаю... Поэтому на всякий случай сыграем еще раз
# Введите номер желаемой темы:
#  1) Журналистика
#  2) Византийская книжность
#  3) Французская кухня
#  2
# _ _ _ _ _ _
# Введите букву, которая, по вашему мнению, есть в этом слове: а
# _ _ _ _ а _
# Введите букву, которая, по вашему мнению, есть в этом слове:
# По-моему, вы ничего не написали. Все же придумайте букву!
# Введите букву, которая, по вашему мнению, есть в этом слове: о
# _ о _ _ а _
# Введите букву, которая, по вашему мнению, есть в этом слове: к
# к о _ _ а к
# Введите букву, которая, по вашему мнению, есть в этом слове:
# Вы уже пробовали эту букву, забыли?
# Введите букву, которая, по вашему мнению, есть в этом слове: н
# к о н _ а к
# Введите букву, которая, по вашему мнению, есть в этом слове: д
# к о н д а к
# Поздравляю! Вас не успели повесить!
# Если хотите продолжить игру, введите "да": нет
# Вы действительно заканчиваете игру? Введите "да" или "нет"да
# До свидания!
